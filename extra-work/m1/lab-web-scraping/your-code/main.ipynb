# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended content.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit the urls below and take a look at their source code through Chrome DevTools. You'll need to identify the html tags, special class names, etc used in the html content you are expected to extract.
#
# **Resources**:
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide)
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are already imported for you. If you prefer to use additional libraries feel free to do it.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import bs4

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
print(url)
# Out:
# https://github.com/trending/developers

# %%
# your code here
response = requests.get(url)
print(url)
# Out:
# https://github.com/trending/developers

# %%
response
# Out:
# <Response [200]>

# %%
html=response.content

# %%
len(html)
# Out:
# 504266

# %%
parsed_html=bs4.BeautifulSoup(html, "html.parser")
parsed_html
# Out:
# <!DOCTYPE html>
#
# <html data-a11y-animated-images="system" data-a11y-link-underlines="true" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# ...

# %%
#parsed_html.head
parsed_html.title
# Out:
# <title>Trending  developers on GitHub today · GitHub</title>

# %%
article=parsed_html.find_all("h1" ,{"class": "h3 lh-condensed"})
len(article)
# Out:
# 25

# %%
article[0]
# Out:
# <h1 class="h3 lh-condensed">
# <a class="Link" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":7396228,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="9fe758f929a23f3de1ff4ced6970f2d8a4efd10bd456adbca03adb1c3caa708a" data-view-component="true" href="/stephenberry">Stephen Berry</a> </h1>

# %%
article[0].contents
# Out:
# ['\n',
#  <a class="Link" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_DEVELOPERS_PAGE","click_target":"OWNER","click_visual_representation":"TRENDING_DEVELOPER","actor_id":null,"record_id":17523360,"originating_url":"https://github.com/trending/developers","user_id":null}}' data-hydro-click-hmac="4a1cb16aa22686069b55fc43fadca4b0211d118c53e3da4fb127fb1e7039402d" data-view-component="true" href="/sxyazi">三咲雅 · Misaki Masa</a>,
#  ' ']

# %%
article[0].contents[1].string
# Out:
# '三咲雅 · Misaki Masa'

# %%
articles_list=[]
for a in article:
    a=str(a)
    soup_a=bs4.BeautifulSoup(a, "html.parser")
    list_a=soup_a.find_all("a")
    for e in list_a:
        articles_list.append(e.string.strip())
articles_list
# Out:
# ['Stephen Berry',
#  'Emil Ernerfeldt',
#  'Me No Dev',
#  'Arpit Bhayani',
#  'Marshall Bowers',
#  'Arseny Kapoulkine',
#  "Nick O'Leary",
#  'Eric Buehler',
#  'Daniel Öster',
#  'Quentin Gallouédec',
#  'Nadeshiko Manju',
#  'Argo Zhang',
#  'LangChain4j',
#  'Aimeos',
#  'CFC4N',
#  'abhishek thakur',
#  'dgtlmoon',
#  'Bram Gerritsen',
#  'bqy_fe',
#  'Andrej',
#  'sigoden',
#  'Mehdi Hadeli',
#  'Tim MacDonald',
#  'Aras Pranckevičius',
#  'Anton Tayanovskyy']

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
parsed_html.head
# Out:
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# ...

# %%
all_tags = [tag.name for tag in parsed_html.find_all(True)] 
list(set(all_tags))
# Out:
# ['title',
#  'img',
#  'a',
#  'ul',
#  'label',
#  'textarea',
#  'details-menu',
#  'form',
#  'div',
#  'body',
#  'svg',
#  'article',
#  'auto-check',
#  'circle',
#  'header',
#  'template',
#  'footer',
#  'scrollable-region',
#  'path',
#  'details',
#  'h2',
#  'span',
#  'ghcc-consent',
#  'head',
#  'query-builder',
#  'details-dialog',
#  'script',
#  'button',
#  'tool-tip',
#  'main',
#  'nav',
#  'react-partial',
#  'filter-input',
#  'li',
#  'dialog',
#  'cookie-consent-link',
#  'input',
#  'html',
#  'dialog-helper',
#  'custom-scopes',
#  'meta',
#  'modal-dialog',
#  'p',
#  'h3',
#  'clipboard-copy',
#  'qbsearch-input',
#  'h1',
#  'summary',
#  'link']

# %%
article = parsed_html.find_all("h1", {"class": "h3 lh-condensed"})
len(article)
# Out:
# 25

# %%
# your code here
articles_list2=[]
for a in article:
    a=str(a)
    soup_a=bs4.BeautifulSoup(a, "html.parser")
    list_a=soup_a.find_all("a")
    for e in list_a:
        articles_list2.append(e.string.strip())
articles_list2
# Out:
# ['Stephen Berry',
#  'Emil Ernerfeldt',
#  'Me No Dev',
#  'Arpit Bhayani',
#  'Marshall Bowers',
#  'Arseny Kapoulkine',
#  "Nick O'Leary",
#  'Eric Buehler',
#  'Daniel Öster',
#  'Quentin Gallouédec',
#  'Nadeshiko Manju',
#  'Argo Zhang',
#  'LangChain4j',
#  'Aimeos',
#  'CFC4N',
#  'abhishek thakur',
#  'dgtlmoon',
#  'Bram Gerritsen',
#  'bqy_fe',
#  'Andrej',
#  'sigoden',
#  'Mehdi Hadeli',
#  'Tim MacDonald',
#  'Aras Pranckevičius',
#  'Anton Tayanovskyy']

# %% [markdown]
# #### Display the trending Python repositories in GitHub.
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'
print(url)
# Out:
# https://github.com/trending/python?since=daily

# %%
# your code here
response = requests.get(url)
# (h2 class={"h3 lh-condensed"})
response
# Out:
# <Response [200]>

# %%
html=response.content
len(html)
# Out:
# 542249

# %%
article[0].contents[1].string
# Out:
# 'Stephen Berry'

# %%
parsed_html = bs4.BeautifulSoup(html, "html.parser")
parsed_html.head
# Out:
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# ...

# %%
type(parsed_html)
# Out:
# bs4.BeautifulSoup

# %%
article_2=parsed_html.find("h2" ,{"class": "h3 lh-condensed"})
article_2
# Out:
# <h2 class="h3 lh-condensed">
# <a class="Link" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"TRENDING_REPOSITORIES_PAGE","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":854347601,"originating_url":"https://github.com/trending/python?since=daily","user_id":null}}' data-hydro-click-hmac="225e751893a2b54cf3d817b36a4801324e38e714169a9853191ffb9f0a6d29be" data-view-component="true" href="/XiaoMi/ha_xiaomi_home"><svg aria-hidden="true" class="octicon octicon-repo mr-1 color-fg-muted" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# ...

# %%
titulo = article_2.get_text(strip=True).split('/')[0].strip()
titulo
# Out:
# 'XiaoMi'

# %%
article_3 = parsed_html.find_all("h2", {"class": "h3 lh-condensed"})

# %%
titulos=[] 
for element in article_3:
    titulo = element.get_text(strip=True).split('/')[0].strip() 
    titulos.append(titulo)
    
titulos
# Out:
# ['XiaoMi',
#  'facebookresearch',
#  'unitreerobotics',
#  'andrewyng',
#  'meta-llama',
#  'seleniumbase',
#  'aio-libs',
#  'hiyouga',
#  'crewAIInc',
#  'MsLolita',
#  'phidatahq',
#  'linyqh']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
# your code here
disney = requests.get(url) #extraemos la url donde se encuentran los datos 
disney
# Out:
# <Response [200]>

# %%
html = disney.content #vemos el contenido

# %%
parsed_html = bs4.BeautifulSoup(html, "html.parser")
parsed_html.head #head que nos muestre la lista pero no todo solo para comrpovar que esta
# Out:
# <head>
# <meta charset="utf-8"/>
# <title>Walt Disney - Wikipedia</title>
# ...

# %%
article_4 = parsed_html.find_all("td")

# %%
img_tag = article_4[0].find("img")
img_tag
# Out:
# <img class="mw-file-element" data-file-height="675" data-file-width="450" decoding="async" height="330" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/330px-Walt_Disney_1946.JPG 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/440px-Walt_Disney_1946.JPG 2x" width="220"/>

# %%
img_url = img_tag["src"]
img_url
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG'

# %%
url_img_list = []                               
for element in article_4:
    url_tag = element.find("img")       
    if url_tag and url_tag.get("src"): 
        url_img = url_tag["src"]           
        url_img_list.append(url_img)

url_img_list
# Out:
# ['//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/1/1b/Nuvola_apps_kaboodle.svg/16px-Nuvola_apps_kaboodle.svg.png',
#  '//upload.wikimedia.org/wikipedia/en/thumb/9/96/Symbol_category_class.svg/16px-Symbol_category_class.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/e/e3/Disneyland_Resort_logo.svg/135px-Disneyland_Resort_logo.svg.png']

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page.

# %%
# This is the url you will scrape in this exercise
url_py ='https://en.wikipedia.org/wiki/Python'

# %%
# your code here
response_py = requests.get(url_py) 
response_py
# Out:
# <Response [200]>

# %%
html_py = response_py.content 
parser_py = BeautifulSoup(html_py,"html.parser")
parser_py.head
# Out:
# <head>
# <meta charset="utf-8"/>
# <title>Python - Wikipedia</title>
# ...

# %%
links = parser_py.find_all("a", href=True)

# %% [markdown]
# #### Find the number of titles that have changed in the United States Code since its last release point.

# %%
# This is the url you will scrape in this exercise
url_usa = 'http://uscode.house.gov/download/download.shtml'

# %%
# your code here
response_usa = requests.get(url_usa) 
response_usa
# Out:
# <Response [200]>

# %%
html_usa = response_usa.content 
parser_usa = BeautifulSoup(html_usa,"html.parser")
parser_usa.head
# Out:
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=8" http-equiv="X-UA-Compatible"/>
# <meta content="no-cache" http-equiv="pragma"/><!-- HTTP 1.0 -->
# <meta content="no-cache,must-revalidate" http-equiv="cache-control"/><!-- HTTP 1.1 -->
# <meta content="0" http-equiv="expires"/>
# <link href="/javax.faces.resource/favicon.ico.xhtml?ln=images" rel="shortcut icon"/><link href="/javax.faces.resource/cssLayout.css.xhtml?ln=css" rel="stylesheet" type="text/css"/><script src="/javax.faces.resource/jsf.js.xhtml?ln=javax.faces" type="text/javascript"></script><link href="/javax.faces.resource/static.css.xhtml?ln=css" rel="stylesheet" type="text/css"/></head>

# %%
titulos_usa = parser_usa.find("div")
titulos_usa
# Out:
# <div id="body">
# <noscript>
# <div style="font-size: 12px; font-family: Arial; background-color: #F0F0FE;">
#             This page is better viewed with a JavaScript enabled browser.
#         </div>
# </noscript>
# <div id="header"><a href="/browse.xhtml;jsessionid=7790D0C8E1B359696CB25CD2626B460E"><img alt="OLRC home" src="/javax.faces.resource/u4.png.xhtml?ln=images" style="border: none;"/></a>
# </div>
# <div style="margin-left: 2px; clear: both;  background-color: rgb(201, 173, 109);"><div id="menu_homeLink">
# ...

# %% [markdown]
# #### Find a Python list with the top ten FBI's Most Wanted names.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
# your code here

# %% [markdown]
# ####  Display the 20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
# your code here

# %% [markdown]
# #### Count the number of tweets by a given Twitter account.
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### Number of followers of a given twitter account
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the followers for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
# your code here

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk.

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
# your code here

# %% [markdown]
# #### Display the top 10 languages by number of native speakers stored in a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
# your code here

# %% [markdown]
# ## Bonus
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### Display IMDB's top 250 data (movie name, initial release, director name and stars) as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code here

# %% [markdown]
# #### Display the movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
# your code here

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = input('Enter the city: ')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code here

# %% [markdown]
# #### Find the book name, price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
# your code here
